# %%
import pandas as pd

# %%
import yfinance as yf
from yahoofinancials import YahooFinancials

# %%
nlp_df = yf.download(['ZM','GME','AMC','UAL','FOXA','DOGE-USD'], 
                      start='2019-01-11', 
                      end='2021-12-01', 
                      progress=False,
)
nlp_df.head()
# Out:
#             Adj Close                                           Close  \
#                   AMC  DOGE-USD FOXA        GME        UAL  ZM    AMC
# Date
# 2019-01-11  12.968035  0.002129  NaN  15.329879  80.070000 NaN  14.03
# 2019-01-12        NaN  0.002148  NaN        NaN        NaN NaN    NaN
# 2019-01-13        NaN  0.002094  NaN        NaN        NaN NaN    NaN
# 2019-01-14  13.060466  0.002183  NaN  15.126770  79.910004 NaN  14.13
# 2019-01-15  13.226842  0.002111  NaN  15.020379  81.199997 NaN  14.31
#
#                                   ... Open                           Volume  \
#             DOGE-USD FOXA    GME  ... FOXA    GME        UAL  ZM        AMC
# Date                              ...
# 2019-01-11  0.002129  NaN  15.85  ...  NaN  15.86  80.680000 NaN   578600.0
# 2019-01-12  0.002148  NaN    NaN  ...  NaN    NaN        NaN NaN        NaN
# 2019-01-13  0.002094  NaN    NaN  ...  NaN    NaN        NaN NaN        NaN
# ...

# %%
nlp_df.shape
# Out:
# (1056, 36)

# %%
nlp_df.to_csv("/Users/Aarushi/Duke/MIDS - Fall 2021/Fall 2021/703_IDS_NLP/Final Project/yf_data.csv", encoding='utf-8', index=False)
